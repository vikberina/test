# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

# %%
directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': []
}

# %%
# p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;
# s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится
# l – list – команда, которая выведет список всех документов в формате
# as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень
# d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок. 
# m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую. 
# a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться.

# %%
command_entered = input('Введите команду:')
command_standart=['p', 's', 'l', 'as', 'd', 'm', 'a']
def print_name(data, number_document):
    i=0
    for row in data:
        if row['number']==number_document:
            i+=1
            print('Результат: Владелец документа:', row['name'])
    if i==0:
        print('Результат: документ не найден в базе')
def print_shelf(data, number_document):
    i=0
    for row in data.items():
        if number_document in row[1]:
            i+=1
            number_shelf = int (row[0])
            print('Результат: документ хранится на полке №{:.0f}'.format(number_shelf))
    if i==0:
        print('Результат: документ не найден в базе')
def print_list(data):
    for row in data:
        print(row['type'], ' \"{}" "{}\" '.format(row['number'], row['name']))
def add_new_shelf(data, number_new_shelf):
    data.setdefault(number_new_shelf,[])
    directories=data
    print(directories)
def delete_people(data_documents, data_directories, delete_number):
    i=0
    for row in data_documents:
        if delete_number== row['number']:
            i+=1
            data_documents.remove(row)
    for row in data_directories.items():
        if delete_number in row[1]:
            list_documents=row[1]
            list_documents.remove(delete_number)
            data_directories.setdefault(row[0], list_documents)
    if i==0:
        print('Удаление невозможно, номер документа введен некорректно!')
    else:
        print('Список документов после удаления:')
        for row in data_documents:
            print(row)
        print('Перечень полок хранения документов:')
        for row in data_directories.items():
            print(row)
def move_document(data, shelf, number_document):
    i=0
    if shelf not in data.keys():
        print('Полки нет')
    else:
        for row in data.items():
            if number_document in row[1]:
                list_documents=row[1]
                list_documents.remove(number_document)
                data.setdefault(row[0], list_documents)
                i+=1
    if i==0:
        print('Документа нет')
    else:
        for row in data.items():
            if move_shelf==row[0]:
                list_documents=row[1]
                list_documents.append(number_document)
                data.setdefault(row[0], list_documents)
        derictories=data
        print(directories)
def add_new_human(data_documents, data_directories, type_document, number_document, name, number_shelf):
    document={}
    document.setdefault('type',[type_document])
    document.setdefault('number',[number_document])
    document.setdefault('name',[name])
    data_documents.append(document)
    for string in data_directories.items():
        if number_shelf==string[0]:
            list_documents=string[1]
            list_documents.append(number_document)
            data_directories.setdefault(string[0], list_documents)
    print('Новый список сотрудников: ')
    for row_1 in data_documents:
        print(row_1)
    print('Полки хранения:')
    for row_2 in data_directories.items():
        print(row_2)
if command_entered not in command_standart:
    print('Введена неверная команда!')
elif command_entered==command_standart[0]:
    number_document=input('Введите номер документа:')
    print_name(documents, number_document)
elif command_entered==command_standart[1]:
    number_document=input('Введите номер документа:')
    print_shelf(directories, number_document)
elif command_entered==command_standart[2]:
    print_list(documents)
elif command_entered==command_standart[3]:
    number_new_shelf=input('Введите номер новой полки')
    add_new_shelf(directories, number_new_shelf)
elif command_entered==command_standart[4]:
    delete =input('Введите номер документа для удаления:')
    delete_people(documents, directories, delete)
elif command_entered==command_standart[5]:
    move_shelf= input('Введите номер полку куда нужно перенести документ:')
    move_number_document=input('Введите номер документа, который нужно перенести:')
    move_document(directories, move_shelf, move_number_document)
elif command_entered==command_standart[6]:
    type_new_document=input('Введите тип нового документа: ')
    number_new_document=input('Введите номер нового документа: ')
    name_new_human=input('Введите имя и фамилию нового сотрудника: ')
    number_shelf_for_new_document=input('Введите полку для храния документов: ')
    if number_shelf_for_new_document not in directories.keys():
        print('Добавление не возможно, сначала добавьте полку для хранения!')
    else:
        add_new_human(documents, directories, type_new_document, number_new_document, name_new_human, number_shelf_for_new_document)
# Out:
# Введите команду:s
# Введите номер документа:10006
# Результат: документ хранится на полке №2
