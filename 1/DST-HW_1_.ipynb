# %%
file = open("/Users/viktoria/Desktop/исследование про выборы/Plenarprotokoll 19:162 .txt", "r")

# %%
data = file.read()

# %%
occurrences = data.count("Russland")
print('Russland :', occurrences)
occurrences = data.count("Moskau")
print('Moskau :', occurrences)
occurrences = data.count("China")
print('China :', occurrences)
occurrences = data.count("Peking")
print('Peking :', occurrences)
occurrences = data.count("Albanien")
print('Albanien :', occurrences)
occurrences = data.count("Tirana")
print('Tirana :', occurrences)
occurrences = data.count("Andorra")
print('Andorra :', occurrences)
occurrences = data.count("Andorra la Vella")
print('Andorra la Vella :', occurrences)
occurrences = data.count("Belgien")
print('Belgien :', occurrences)
occurrences = data.count("Brüssel")
print('Brüssel :', occurrences)
occurrences = data.count("Bosnien und Herzegowina")
print('Bosnien und Herzegowina :', occurrences)
occurrences = data.count("Sarajevo")
print('Sarajevo :', occurrences)
occurrences = data.count("Bulgarien")
print('Bulgarien :', occurrences)
occurrences = data.count("Sofia")
print('Sofia :', occurrences)
occurrences = data.count("Dänemark")
print('Dänemark :', occurrences)
occurrences = data.count("Kopenhagen")
print('Kopenhagen :', occurrences)
occurrences = data.count("Estland")
print('Estland :', occurrences)
occurrences = data.count("Tallinn")
print('Tallinn :', occurrences)
occurrences = data.count("Finnland")
print('Finnland :', occurrences)
occurrences = data.count("Helsinki")
print('Helsinki :', occurrences)
occurrences = data.count("Frankreich")
print('Frankreich :', occurrences)
occurrences = data.count("Paris")
print('Paris :', occurrences)
occurrences = data.count("Griechenland")
print('Griechenland :', occurrences)
occurrences = data.count("Athen")
print('Athen :', occurrences)
occurrences = data.count("Grönland")
print('Grönland :', occurrences)
occurrences = data.count("Nuuk")
print('Nuuk :', occurrences)
occurrences = data.count("Irland")
print('Irland :', occurrences)
occurrences = data.count("Dublin")
print('Dublin :', occurrences)
occurrences = data.count("Island")
print('Island :', occurrences)
occurrences = data.count("Reykjavik")
print('Reykjavik :', occurrences)
occurrences = data.count("Italien")
print('Italien :', occurrences)
occurrences = data.count("Rom")
print('Rom :', occurrences)
occurrences = data.count("Kosovo")
print('Kosovo :', occurrences)
occurrences = data.count("Pristina")
print('Pristina :', occurrences)
occurrences = data.count("Kroatien")
print('Kroatien :', occurrences)
occurrences = data.count("Zagreb")
print('Zagreb :', occurrences)
occurrences = data.count("Lettland")
print('Lettland :', occurrences)
occurrences = data.count("Riga")
print('Riga :', occurrences)
occurrences = data.count("Liechtenstein")
print('Liechtenstein :', occurrences)
occurrences = data.count("Vaduz")
print('Vaduz :', occurrences)
occurrences = data.count("Litauen")
print('Litauen :', occurrences)
occurrences = data.count("Vilnius")
print('Vilnius :', occurrences)
occurrences = data.count("Wilna")
print('Wilna :', occurrences)
occurrences = data.count("Luxemburg")
print('Luxemburg :', occurrences)
occurrences = data.count("Mazedonien")
print('Mazedonien :', occurrences)
occurrences = data.count("Nordmazedonien")
print('Nordmazedonien :', occurrences)
occurrences = data.count("Skopje")
print('Skopje :', occurrences)
occurrences = data.count("Malta")
print('Malta :', occurrences)
occurrences = data.count("Valletta")
print('Valletta :', occurrences)
occurrences = data.count("Moldawien")
print('Moldawien :', occurrences)
occurrences = data.count("Moldau")
print('Moldau :', occurrences)
occurrences = data.count("Chisinau")
print('Chisinau :', occurrences)
occurrences = data.count("Monaco")
print('Monaco :', occurrences)
occurrences = data.count("Monaco-Ville")
print('Monaco-Ville :', occurrences)
occurrences = data.count("Montenegro")
print('Montenegro :', occurrences)
occurrences = data.count("Podgorica")
print('Podgorica :', occurrences)
occurrences = data.count("Niederlande")
print('Niederlande :', occurrences)
occurrences = data.count("Amsterdam")
print('Amsterdam :', occurrences)
occurrences = data.count("Norwegen")
print('Norwegen :', occurrences)
occurrences = data.count("Oslo")
print('Oslo :', occurrences)
occurrences = data.count("Österreich")
print('Österreich :', occurrences)
occurrences = data.count("Wien")
print('Wien :', occurrences)
occurrences = data.count("Polen")
print('Polen :', occurrences)
occurrences = data.count("Warschau")
print('Warschau :', occurrences)
occurrences = data.count("Portugal")
print('Portugal :', occurrences)
occurrences = data.count("Lissabon")
print('Lissabon :', occurrences)
occurrences = data.count("Rumänien")
print('Rumänien :', occurrences)
occurrences = data.count("Bukarest")
print('Bukarest :', occurrences)
occurrences = data.count("San Marino")
print('San Marino :', occurrences)
occurrences = data.count("Schweden")
print('Schweden :', occurrences)
occurrences = data.count("Stockholm")
print('Stockholm :', occurrences)
occurrences = data.count("Schweiz")
print('Schweiz :', occurrences)
occurrences = data.count("Bern")
print('Bern :', occurrences)
occurrences = data.count("Serbien")
print('Serbien :', occurrences)
occurrences = data.count("Belgrad")
print('Belgrad :', occurrences)
occurrences = data.count("Slowakei")
print('Slowakei :', occurrences)
occurrences = data.count("Bratislava")
print('Bratislava :', occurrences)
occurrences = data.count("Slowenien")
print('Slowenien :', occurrences)
occurrences = data.count("Ljubljana")
print('Ljubljana :', occurrences)
occurrences = data.count("Spanien")
print('Spanien :', occurrences)
occurrences = data.count("Madrid")
print('Madrid :', occurrences)
occurrences = data.count("Tschechien")
print('Tschechien :', occurrences)
occurrences = data.count("Prag")
print('Prag :', occurrences)
occurrences = data.count("Tschechische Republik")
print('Tschechische Republik :', occurrences)
occurrences = data.count("Türkei")
print('Türkei :', occurrences)
occurrences = data.count("Ankara")
print('Ankara :', occurrences)
ccurrences = data.count("Ukraine")
print('Ukraine :', occurrences)
ccurrences = data.count("Kiew")
print('Kiew :', occurrences)
occurrences = data.count("Ungarn")
print('Ungarn :', occurrences)
occurrences = data.count("Budapest")
print('Budapest :', occurrences)
occurrences = data.count("Vatikan")
print('Vatikan :', occurrences)
occurrences = data.count("Vatikanstadt")
occurrences = data.count("Weißrussland")
print('Weißrussland :', occurrences)
occurrences = data.count("Belarus")
print('Belarus :', occurrences)
occurrences = data.count("Minsk")
print('Minsk :', occurrences)
occurrences = data.count("Zypern")
print('Zypern :', occurrences)
occurrences = data.count("Nikosia")
print('Nikosia :', occurrences)
occurrences = data.count("Kanada")
print('Kanada :', occurrences)
occurrences = data.count("Ottawa")
print('Ottawa :', occurrences)
occurrences = data.count("Mexico")
print('Mexico :', occurrences)
occurrences = data.count("Mexiko-Stadt")
print('Mexiko-Stadt :', occurrences)
occurrences = data.count("USA")
print('USA :', occurrences)
occurrences = data.count("Washington")
print('Washington :', occurrences)
occurrences = data.count("Kuba")
print('Kuba :', occurrences)
occurrences = data.count("Havanna")
print('Havanna :', occurrences)
occurrences = data.count("Dominikanische Republik")
print('Dominikanische Republik :', occurrences)
occurrences = data.count("Dominikana")
print('Dominikana :', occurrences)
occurrences = data.count("Santo Domingo")
print('Santo Domingo :', occurrences)
occurrences = data.count("Costa Rica")
print('Costa Rica :', occurrences)
occurrences = data.count("San José")
print('San José :', occurrences)
occurrences = data.count("Guadeloupe")
print('Guadeloupe :', occurrences)
occurrences = data.count("Basse-Terre")
print('Basse-Terre :', occurrences)
occurrences = data.count("Honduras")
print('Honduras :', occurrences)
occurrences = data.count("Tegucigalpa")
print('Tegucigalpa :', occurrences)
occurrences = data.count("Grenada")
print('Grenada :', occurrences)
occurrences = data.count("St. George’s")
print('St. George’s :', occurrences)
occurrences = data.count("Haiti")
print('Haiti :', occurrences)
occurrences = data.count("Port-au-Prince")
print('Port-au-Prince :', occurrences)
occurrences = data.count("Argentinien")
print('Argentinien :', occurrences)
occurrences = data.count("Buenos Aires")
print('Buenos Aires :', occurrences)
occurrences = data.count("Bolivien")
print('Bolivien :', occurrences)
occurrences = data.count("Sucre")
print('Sucre :', occurrences)
occurrences = data.count("Brasilien")
print('Brasilien :', occurrences)
occurrences = data.count("Brasilia")
print('Brasilia :', occurrences)
occurrences = data.count("Chile")
print('Chile :', occurrences)
occurrences = data.count("Santiago")
print('Santiago :', occurrences)
occurrences = data.count("Ecuador")
print('Ecuador :', occurrences)
occurrences = data.count("Quito")
print('Quito :', occurrences)
occurrences = data.count("Guyana")
print('Guyana :', occurrences)
occurrences = data.count("Georgetown")
print('Georgetown :', occurrences)
occurrences = data.count("Kolumbien")
print('Kolumbien :', occurrences)
occurrences = data.count("Bogota")
print('Bogota :', occurrences)
occurrences = data.count("Paraguay")
print('Paraguay :', occurrences)
occurrences = data.count("Asuncion")
print('Asuncion :', occurrences)
occurrences = data.count("Peru")
print('Peru :', occurrences)
occurrences = data.count("Lima")
print('Lima :', occurrences)
occurrences = data.count("Suriname")
print('Suriname :', occurrences)
occurrences = data.count("Paramaribo")
print('Paramaribo :', occurrences)
occurrences = data.count("Französisch Guyana")
print('Französisch Guyana :', occurrences)
occurrences = data.count("Cayenne")
print('Cayenne :', occurrences)
occurrences = data.count("Uruguay")
print('Uruguay :', occurrences)
occurrences = data.count("Montevideo")
print('Montevideo :', occurrences)
occurrences = data.count("Venezuela")
print('Venezuela :', occurrences)
occurrences = data.count("Caracas")
print('Caracas :', occurrences)
occurrences = data.count("Syrien")
print('Syrien :', occurrences)
occurrences = data.count("Damaskus")
print('Damaskus :', occurrences)
occurrences = data.count("Irak")
print('Irak :', occurrences)
occurrences = data.count("Bagdad")
print('Bagdad :', occurrences)
occurrences = data.count("Libanon")
print('Libanon :', occurrences)
occurrences = data.count("Beirut")
print('Beirut :', occurrences)
occurrences = data.count("Israel")
print('Israel :', occurrences)
occurrences = data.count("Jerusalem")
print('Jerusalem :', occurrences)
occurrences = data.count("Jordanien")
print('Jordanien :', occurrences)
occurrences = data.count("Amman")
print('Amman :', occurrences)
occurrences = data.count("Saudi-Arabien")
print('Saudi-Arabien :', occurrences)
occurrences = data.count("Riad")
print('Riad :', occurrences)
occurrences = data.count("Kuwait")
print('Kuwait :', occurrences)
occurrences = data.count("Bahrain")
print('Bahrain :', occurrences)
occurrences = data.count("Manama")
print('Manama :', occurrences)
occurrences = data.count("Katar")
print('Katar :', occurrences)
occurrences = data.count("Doha")
print('Doha :', occurrences)
occurrences = data.count("Vereinigte Arabische Emirate")
print('Vereinigte Arabische Emirate :', occurrences)
occurrences = data.count("Abu Dhabi")
print('Abu Dhabi :', occurrences)
occurrences = data.count("Oman")
print('Oman :', occurrences)
occurrences = data.count("Maskat")
print('Maskat :', occurrences)
occurrences = data.count("Jemen")
print('Jemen :', occurrences)
occurrences = data.count("Sanaa")
print('Sanaa :', occurrences)
occurrences = data.count("Iran")
print('Iran :', occurrences)
occurrences = data.count("Teheran")
print('Teheran :', occurrences)
occurrences = data.count("Ägypten")
print('Ägypten :', occurrences)
occurrences = data.count("Kairo")
print('Kairo :', occurrences)
occurrences = data.count("Algerien")
print('Algerien :', occurrences)
occurrences = data.count("Algier")
print('Algier :', occurrences)
occurrences = data.count("Libyen")
print('Libyen :', occurrences)
occurrences = data.count("Tripolis")
print('Tripolis :', occurrences)
occurrences = data.count("Marokko")
print('Marokko :', occurrences)
occurrences = data.count("Rabat")
print('Rabat :', occurrences)
occurrences = data.count("Sudan")
print('Sudan :', occurrences)
occurrences = data.count("Khartum")
print('Khartum :', occurrences)
occurrences = data.count("Tunesien")
print('Tunesien :', occurrences)
occurrences = data.count("Tunis")
print('Tunis :', occurrences)
occurrences = data.count("Westsahara")
print('Westsahara :', occurrences)
occurrences = data.count("El Aaiún")
print('El Aaiún :', occurrences)
occurrences = data.count("Mauretanien")
print('Mauretanien :', occurrences)
occurrences = data.count("Nouakchott")
print('Nouakchott :', occurrences)
occurrences = data.count("Senegal")
print('Senegal :', occurrences)
occurrences = data.count("Dakar")
print('Dakar :', occurrences)
occurrences = data.count("Mali")
print('Mali :', occurrences)
occurrences = data.count("Bamako")
print('Bamako :', occurrences)
occurrences = data.count("Guinea")
print('Guinea :', occurrences)
occurrences = data.count("Conakry")
print('Conakry :', occurrences)
occurrences = data.count("Sierra Leone")
print('Sierra Leone :', occurrences)
occurrences = data.count("Freetown")
print('Freetown :', occurrences)
occurrences = data.count("Tschad")
print('Tschad :', occurrences)
occurrences = data.count("Burkina Faso")
print('Burkina Faso :', occurrences)
occurrences = data.count("Ouagadougou")
print('Ouagadougou :', occurrences)
occurrences = data.count("Benin")
print('Benin :', occurrences)
occurrences = data.count("Porto-Novo")
print('Porto-Novo :', occurrences)
occurrences = data.count("Gambia")
print('Gambia :', occurrences)
occurrences = data.count("Banjul")
print('Banjul :', occurrences)
occurrences = data.count("Guinea-Bissau")
print('Guinea-Bissau :', occurrences)
occurrences = data.count("Bissau")
print('Bissau :', occurrences)
occurrences = data.count("Liberia")
print('Liberia :', occurrences)
occurrences = data.count("Monrovia")
print('Monrovia :', occurrences)
occurrences = data.count("Côte d’Ivoire")
print('Côte d’Ivoire :', occurrences)
occurrences = data.count("Yamoussoukro")
print('Yamoussoukro :', occurrences)
occurrences = data.count("Ghana")
print('Ghana :', occurrences)
occurrences = data.count("Accra")
print('Accra :', occurrences)
occurrences = data.count("Nigeria")
print('Nigeria :', occurrences)
occurrences = data.count("Abuja")
print('Abuja :', occurrences)
occurrences = data.count("Togo")
print('Togo :', occurrences)
occurrences = data.count("Lomé")
print('Lomé :', occurrences)
occurrences = data.count("Kamerun")
print('Kamerun :', occurrences)
occurrences = data.count("Jaunde")
print('Jaunde :', occurrences)
occurrences = data.count("Gabun")
print('Gabun :', occurrences)
occurrences = data.count("Libreville")
print('Libreville :', occurrences)
occurrences = data.count("Zentralafrikanische Republik")
print('Zentralafrikanische Republik :', occurrences)
occurrences = data.count("Bangui")
print('Bangui :', occurrences)
occurrences = data.count("Kongo")
print('Kongo :', occurrences)
occurrences = data.count("Brazzaville")
print('Brazzaville :', occurrences)
occurrences = data.count("Kinshasa")
print('Kinshasa :', occurrences)
occurrences = data.count("Südsudan")
print('Südsudan :', occurrences)
occurrences = data.count("Dschuba")
print('Dschuba :', occurrences)
occurrences = data.count("Äthiopien")
print('Äthiopien :', occurrences)
occurrences = data.count("Addis Abeba")
print('Addis Abeba :', occurrences)
occurrences = data.count("Uganda")
print('Uganda :', occurrences)
occurrences = data.count("Kampala")
print('Kampala  :', occurrences)
occurrences = data.count("Kenia")
print('Kenia :', occurrences)
occurrences = data.count("Nairobi")
print('Nairobi  :', occurrences)
occurrences = data.count("Somalia")
print('Somalia :', occurrences)
occurrences = data.count("Mogadischu")
print('Mogadischu  :', occurrences)
occurrences = data.count("Tansania")
print('Tansania :', occurrences)
occurrences = data.count("Dodoma")
print('Dodoma :', occurrences)
occurrences = data.count("Eritrea")
print('Eritrea:', occurrences)
occurrences = data.count("Asmara")
print('Asmara :', occurrences)
occurrences = data.count("Mosambik")
print('Mosambik:', occurrences)
occurrences = data.count("Maputo")
print('Maputo :', occurrences)
occurrences = data.count("Angola")
print('Angola:', occurrences)
occurrences = data.count("Luanda ")
print('Luanda  :', occurrences)
occurrences = data.count("Sambia")
print('Sambia:', occurrences)
occurrences = data.count("Lusaka")
print('Lusaka :', occurrences)
occurrences = data.count("Simbabwe")
print('Simbabwe:', occurrences)
occurrences = data.count("Harare")
print('Harare :', occurrences)
occurrences = data.count("Namibia")
print('Namibia:', occurrences)
occurrences = data.count("Windhoek")
print('Windhoek:', occurrences)
occurrences = data.count("Botsuana")
print('Botsuana:', occurrences)
occurrences = data.count("Gaborone")
print('Gaborone:', occurrences)
occurrences = data.count("Swasiland")
print('Swasiland:', occurrences)
occurrences = data.count("Mbabane")
print('Mbabane:', occurrences)
occurrences = data.count("Malawi")
print('Malawi:', occurrences)
occurrences = data.count("Lilongwe")
print('Lilongwe:', occurrences)
occurrences = data.count("Lesoto")
print('Lesoto:', occurrences)
occurrences = data.count("Maseru")
print('Maseru:', occurrences)
occurrences = data.count("Republik Südafrika")
print('Republik Südafrika:', occurrences)
occurrences = data.count("Kapstadt")
print('Kapstadt:', occurrences)
occurrences = data.count("Madagaskar")
print('Madagaskar:', occurrences)
occurrences = data.count("Antananarivo")
print('Antananarivo :', occurrences)
occurrences = data.count("Mongolei")
print('Mongolei :', occurrences)
occurrences = data.count("Ulaanbaatar")
print('Ulaanbaatar :', occurrences)
occurrences = data.count("Japan")
print('Japan :', occurrences)
occurrences = data.count("Tokio")
print('Tokio :', occurrences)
occurrences = data.count("Nordkorea")
print('Nordkorea :', occurrences)
occurrences = data.count("Pjöngjang")
print('Pjöngjang :', occurrences)
occurrences = data.count("Südkorea")
print('Südkorea :', occurrences)
occurrences = data.count("Seoul")
print('Seoul :', occurrences)
occurrences = data.count("Bangladesch")
print('Bangladesch :', occurrences)
occurrences = data.count("Dhaka")
print('Dhaka :', occurrences)
occurrences = data.count("Bhutan")
print('Bhutan :', occurrences)
occurrences = data.count("Thimphu")
print('Thimphu :', occurrences)
occurrences = data.count("Indien")
print('Indien :', occurrences)
occurrences = data.count("Neu-Delhi")
print('Neu-Delhi :', occurrences)
occurrences = data.count("Malediven")
print('Malediven :', occurrences)
occurrences = data.count("Male")
print('Male :', occurrences)
occurrences = data.count("Nepal")
print('Nepal :', occurrences)
occurrences = data.count("Kathmandu")
print('Kathmandu :', occurrences)
occurrences = data.count("Pakistan")
print('Pakistan :', occurrences)
occurrences = data.count("Islamabad")
print('Islamabad :', occurrences)
occurrences = data.count("Sri Lanka")
print('Sri Lanka :', occurrences)
occurrences = data.count("Colombo")
print('Colombo :', occurrences)
occurrences = data.count("Brunei")
print('Brunei :', occurrences)
occurrences = data.count("Bandar Seri Begawan")
print('Bandar Seri Begawan :', occurrences)
occurrences = data.count("Indonesien")
print('Indonesien :', occurrences)
occurrences = data.count("Jakarta")
print('Jakarta :', occurrences)
occurrences = data.count("Kambodscha")
print('Kambodscha :', occurrences)
occurrences = data.count("Phnom Penh")
print('Phom Pehn :', occurrences)
occurrences = data.count("Laos")
print('Laos :', occurrences)
occurrences = data.count("Vientiane")
print('Vientiane :', occurrences)
occurrences = data.count("Malaysia")
print('Malaysia :', occurrences)
occurrences = data.count("Kuala Lumpur")
print('Kuala Lumpur :', occurrences)
occurrences = data.count("Philippinen")
print('Philippinen :', occurrences)
occurrences = data.count("Manila")
print('Manila :', occurrences)
occurrences = data.count("Singapur")
print('Singapur :', occurrences)
occurrences = data.count("Myanmar")
print('Myanmar :', occurrences)
occurrences = data.count("Naypyidaw")
print('Naypyidaw :', occurrences)
occurrences = data.count("Thailand")
print('Thailand :', occurrences)
occurrences = data.count("Bangkok")
print('Bangkok :', occurrences)
occurrences = data.count("Osttimor")
print('Osttimor :', occurrences)
occurrences = data.count("Dili")
print('Dili :', occurrences)
occurrences = data.count("Vietnam")
print('Vietnam :', occurrences)
occurrences = data.count("Hanoi")
print('Hanoi :', occurrences)
occurrences = data.count("Armenien")
print('Armenien :', occurrences)
occurrences = data.count("Jerewan")
print('Jerewan :', occurrences)
occurrences = data.count("Eriwan")
print('Eriwan :', occurrences)
occurrences = data.count("Aserbaidschan")
print('Aserbaidschan :', occurrences)
occurrences = data.count("Baku")
print('Baku :', occurrences)
occurrences = data.count("Georgien")
print('Georgien :', occurrences)
occurrences = data.count("Tbilissi")
print('Tbilissi :', occurrences)
occurrences = data.count("Afghanistan")
print('Afghanistan :', occurrences)
occurrences = data.count("Kabul")
print('Kabul :', occurrences)
occurrences = data.count("Kasachstan")
print('Kasachstan :', occurrences)
occurrences = data.count("Nur-Sultan")
print('Nur-Sultan :', occurrences)
occurrences = data.count("Kirgistan")
print('Kirgistan :', occurrences)
occurrences = data.count("Bischkek")
print('Bischkek :', occurrences)
occurrences = data.count("Tadschikistan")
print('Tadschikistan :', occurrences)
occurrences = data.count("Duschanbe")
print('Duschanbe :', occurrences)
occurrences = data.count("Turkmenistan")
print('Turkmenistan :', occurrences)
occurrences = data.count("Aschgabad")
print('Aschgabad :', occurrences)
occurrences = data.count("Usbekistan")
print('Usbekistan :', occurrences)
occurrences = data.count("Taschkent")
print('Taschkent :', occurrences)
occurrences = data.count("Australien")
print('Australien :', occurrences)
occurrences = data.count("Canberra")
print('Canberra :', occurrences)
occurrences = data.count("Papua-Neuguinea")
print('Papua-Neuguinea :', occurrences)
occurrences = data.count("Neuseeland")
print('Neuseeland :', occurrences)
occurrences = data.count("Wellington")
print('Wellington :', occurrences)
occurrences = data.count("Nordirland")
print('Nordirland :', occurrences)
occurrences = data.count("Belfast ")
print('Belfast  :', occurrences)
occurrences = data.count("Großbritannien")
print('Großbritannien :', occurrences)
occurrences = data.count("London")
print('London :', occurrences)
occurrences = data.count("Jamaika")
print('Jamaika :', occurrences)
occurrences = data.count("Kingston")
print('Kingston :', occurrences)
occurrences = data.count("Bahamas")
print('Bahamas :', occurrences)
occurrences = data.count("Nassau")
print('Nassau :', occurrences)
occurrences = data.count("Panama")
print('Panama :', occurrences)
occurrences = data.count("Nikaragua")
print('Nikaragua :', occurrences)
occurrences = data.count("Managua")
print('Managua :', occurrences)
occurrences = data.count("Puerto Rico")
print('Puerto Rico :', occurrences)
occurrences = data.count("San Juan")
print('San Juan :', occurrences)
occurrences = data.count("Guatemala")
print('Guatemala :', occurrences)
occurrences = data.count("Ruanda")
print('Ruanda :', occurrences)
occurrences = data.count("Kigali")
print('Kigali :', occurrences)
occurrences = data.count("Burundi")
print('Burundi :', occurrences)
occurrences = data.count("Gitega")
print('Gitega :', occurrences)
occurrences = data.count("Niger")
print('Niger :', occurrences)
occurrences = data.count("Niamey")
print('Niamey :', occurrences)
occurrences = data.count("Belize")
print('Belize :', occurrences)
occurrences = data.count("Belmopan")
print('Belmopan :', occurrences)
occurrences = data.count("El Salvado")
print('El Salvado :', occurrences)
# Out:
# Russland : 5
# Moskau : 1
# China : 17
# Peking : 2
# Albanien : 2
# Tirana : 2
# Andorra : 0
# Andorra la Vella : 0
# Belgien : 10
# Brüssel : 8
# Bosnien und Herzegowina : 2
# Sarajevo : 0
# Bulgarien : 2
# Sofia : 2
# Dänemark : 6
# Kopenhagen : 2
# Estland : 2
# Tallinn : 2
# Finnland : 2
# Helsinki : 2
# Frankreich : 12
# Paris : 2
# Griechenland : 2
# Athen : 2
# Grönland : 0
# Nuuk : 0
# Irland : 2
# Dublin : 2
# Island : 2
# Reykjavik : 2
# Italien : 4
# Rom : 5
# Kosovo : 2
# Pristina : 2
# Kroatien : 2
# Zagreb : 2
# Lettland : 2
# Riga : 2
# Liechtenstein : 0
# Vaduz : 0
# Litauen : 2
# Vilnius : 0
# Wilna : 2
# Luxemburg : 9
# Mazedonien : 0
# Nordmazedonien : 2
# Skopje : 2
# Malta : 2
# Valletta : 2
# Moldawien : 0
# Moldau : 2
# Chisinau : 2
# Monaco : 0
# Monaco-Ville : 0
# Montenegro : 2
# Podgorica : 2
# Niederlande : 4
# Amsterdam : 3
# Norwegen : 2
# Oslo : 3
# Österreich : 4
# Wien : 7
# Polen : 5
# Warschau : 2
# Portugal : 2
# Lissabon : 3
# Rumänien : 2
# ...
