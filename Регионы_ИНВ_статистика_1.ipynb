# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
# Шаг 1. Открываем файл где приведена структура данных. 
# Мы видим что G 22 - Сумма уменьшения налога в федеральный бюджет при применении инвестиционного налогового вычета, G23 - это сумма вычета, G24-количество налогоплательщиков, применивших вычет
# во всех наших случаях структура одинаковая. В некоторых указана единица измерения в тыс. Для примера открываю ниже

# %%
log=pd.read_csv('/Users/victoria/Downloads/structure-20210701.csv', sep=';')
log[['Id','Field name']].head(26)
# Out:
#       Id  \
# 0     GA
# 1     GB
# 2     G1
# 3     G2
# 4     G3
# 5     G4
# 6     G5
# 7     G6
# 8     G7
# 9     G8
# 10    G9
# 11   G10
# 12   G11
# 13   G12
# 14   G13
# 15   G14
# 16   G15
# 17   G16
# 18   G17
# 19   G18
# 20   G19
# 21   G20
# 22   G21
# 23   G22
# 24   G23
# 25   G24
#
#                                                                                                                                                                            Field name
# 0                                                                                                                                                                         Субъекты РФ
# 1                                                                                                                         Доходы от реализации по прибыльным организациям (тыс.руб.)
# ...

# %%
# открываем файл на 01.09.2021, где приведены субъекты (почему-то он сейчас изчез с сайта налоговой, но сохранился у меня на компе)
# Выводим только нужные нам стобцы G22 G23 и G24

# %%
dt=pd.read_csv('/Users/victoria/Downloads/данные_1.csv', sep=';')
dt[['GA','G22', 'G23','G24']].head(88)
# Out:
#                                    GA      G22        G23  G24
# 0                   Республика Адыгея        0          0    0
# 1                 Республика Башкирия   12 342     32 192    6
# 2                  Республика Бурятия        0          0    0
# 3                    Республика Алтай        0          0    0
# 4                 Республика Дагестан        0          0    0
# 5                Республика Ингушетия        0          0    0
# 6       Республика Кабардино-Балкария       12         67    1
# 7                 Республика Калмыкия        0          0    0
# 8      Республика Карачаево-Черкессия        0          0    0
# 9                  Республика Карелия        0          0    0
# 10                    Республика Коми        0          0    0
# 11                    Республика Крым        0          0    0
# 12                Республика Марий Эл        0          0    0
# 13                Республика Мордовия        0          0    0
# ...

# %%
# открываем файл на 01.07.2021, где приведены субъекты (только нужные столбцы)

# %%
dt=pd.read_csv('/Users/victoria/Downloads/data-20210701-structure-20210701.csv', sep=';')
dt[['GA','G22', 'G23','G24']].head(88)
# Out:
#                                    GA     G22      G23  G24
# 0                   Республика Адыгея       0        0    0
# 1                 Республика Башкирия   6 737   11 925    6
# 2                  Республика Бурятия       0        0    0
# 3                    Республика Алтай       0        0    0
# 4                 Республика Дагестан       0        0    0
# 5                Республика Ингушетия       0        0    0
# 6       Республика Кабардино-Балкария       0        0    0
# 7                 Республика Калмыкия       0        0    0
# 8      Республика Карачаево-Черкессия       0        0    0
# 9                  Республика Карелия       0        0    0
# 10                    Республика Коми       0        0    0
# 11                    Республика Крым       0        0    0
# 12                Республика Марий Эл       0        0    0
# 13                Республика Мордовия       0        0    0
# 14           Республика Саха (Якутия)       0        0    0
# ...

# %%
# открываем файл на 01.04.2021, где приведены субъекты (только нужные столбцы)

# %%
dt=pd.read_csv('/Users/victoria/Downloads/data-20210401-structure-20210401.csv', sep=';')
dt[['GA','G22', 'G23','G24']].head(88)
# Out:
#                                    GA     G22      G23  G24
# 0                   Республика Адыгея       0        0    0
# 1                 Республика Башкирия     846    6 346    5
# 2                  Республика Бурятия       0        0    0
# 3                    Республика Алтай       0        0    0
# 4                 Республика Дагестан       0        0    0
# 5                Республика Ингушетия       0        0    0
# 6       Республика Кабардино-Балкария       0        0    0
# 7                 Республика Калмыкия       0        0    0
# 8      Республика Карачаево-Черкессия       0        0    0
# 9                  Республика Карелия       0        0    0
# 10                    Республика Коми       0        0    0
# 11                    Республика Крым       0        0    0
# 12                Республика Марий Эл       0        0    0
# 13                Республика Мордовия       0        0    0
# 14           Республика Саха (Якутия)       0        0    0
# ...

# %%
# открываем файл на 31.12.2020, где приведены субъекты (только нужные столбцы). Обращаю внимание немного изменился порядок субъектов

# %%
dt=pd.read_csv('/Users/victoria/Downloads/data-20201231-structure-20201231.csv', sep=';')
dt[['GA','G22', 'G23','G24']].head(88)
# Out:
#                                    GA     G22      G23  G24
# 0                   Республика Адыгея       0        0    0
# 1                 Республика Башкирия   5 851    9 100    3
# 2                  Республика Бурятия       0        0    0
# 3                    Республика Алтай       0        0    0
# 4                 Республика Дагестан       0        0    0
# 5                Республика Ингушетия       0        0    0
# 6       Республика Кабардино-Балкария       0        0    0
# 7                 Республика Калмыкия       0        0    0
# 8      Республика Карачаево-Черкессия       0        0    0
# 9                  Республика Карелия       0        0    0
# 10                    Республика Коми       0        0    0
# 11                Республика Марий Эл       0        0    0
# 12                Республика Мордовия       0        0    0
# 13           Республика Саха (Якутия)       0        0    0
# 14         Республика северная Осетия       0        0    0
# ...

# %%
# открываем файл на 01.01.2020, где приведены субъекты (только нужные столбцы).

# %%
dt=pd.read_csv('/Users/victoria/Downloads/data-20200101-structure-20200101.csv', sep=';')
dt[['GA','G22', 'G23','G24']].head(88)
# Out:
#                                    GA        G22         G23  G24
# 0                   Республика Адыгея          0           0    0
# 1                 Республика Башкирия          0           0    0
# 2                  Республика Бурятия          0           0    0
# 3                    Республика Алтай          0           0    0
# 4                 Республика Дагестан          0           0    0
# 5                Республика Ингушетия          0           0    0
# 6       Республика Кабардино-Балкария          0           0    0
# 7                 Республика Калмыкия          0           0    0
# 8      Республика Карачаево-Черкессия          0           0    0
# 9                  Республика Карелия          0           0    0
# 10                    Республика Коми          0           0    0
# 11                Республика Марий Эл          0           0    0
# 12                Республика Мордовия          0           0    0
# ...
